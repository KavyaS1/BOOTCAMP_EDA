# %% [markdown]
# <a href="https://colab.research.google.com/github/KavyaS1/BOOTCAMP_EDA/blob/main/Bootcamp_EDA_Study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks"
# Out:
# 'Another copy of homework_II.ipynb'
#  bootcamp_eda_case
# 'Copy of data_apis.ipynb'
# 'Copy of data-types (1).ipynb'
# 'Copy of data-types.ipynb'
# 'Copy of EDA_activity (1).ipynb'
# 'Copy of EDA_activity.ipynb'
# 'Copy of exercises.ipynb'
# 'Copy of functions.ipynb'
# 'Copy of homework_II.ipynb'
# 'Copy of iteration.ipynb'
# 'Copy of oop (1).ipynb'
# 'Copy of oop.ipynb'
# 'Copy of pandas_intro.ipynb'
# 'Copy of pandas_practice (1).ipynb'
# 'Copy of pandas_practice.ipynb'
# 'Copy of plotting_activity.ipynb'
# 'Copy of plotting_seaborn.ipynb'
# 'Copy of Song Shuffle Simulation Starter Notebook (1).ipynb'
# 'Copy of Song Shuffle Simulation Starter Notebook.ipynb'
# 'Copy of syllabus.ipynb'

# %%
import pandas as pd

app = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/bootcamp_eda_case/application_data.csv.zip", compression = "zip")
prev = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/bootcamp_eda_case/previous_application.csv.zip", compression = "zip")

# %%
education = app.groupby("NAME_EDUCATION_TYPE")["TARGET"].mean()

# %%
education * 100
# Out:
# NAME_EDUCATION_TYPE
# Academic degree                   1.829268
# Higher education                  5.355115
# Incomplete higher                 8.484966
# Lower secondary                  10.927673
# Secondary / secondary special     8.939929
# Name: TARGET, dtype: float64

# %%
app.groupby("DAYS_ID_PUBLISH")["TARGET"].mean()
# Out:
# DAYS_ID_PUBLISH
# -7197    0.000000
# -6551    0.000000
# -6383    0.000000
# -6337    0.000000
# -6274    0.000000
#            ...
# -4       0.122807
# -3       0.078431
# -2       0.120000
# -1       0.125000
#  0       0.125000
# Name: TARGET, Length: 6168, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

app.groupby("NAME_EDUCATION_TYPE")["TARGET"].mean()

sns.barplot(data=app, x="TARGET", y="NAME_EDUCATION_TYPE")
# Out:
# <Axes: xlabel='TARGET', ylabel='NAME_EDUCATION_TYPE'>

# %%
app.groupby("NAME_INCOME_TYPE")["TARGET"].mean() * 100
# Out:
# NAME_INCOME_TYPE
# Businessman              0.000000
# Commercial associate     7.484257
# Maternity leave         40.000000
# Pensioner                5.386366
# State servant            5.754965
# Student                  0.000000
# Unemployed              36.363636
# Working                  9.588472
# Name: TARGET, dtype: float64

# %%
sns.barplot(data=app, x="TARGET", y="NAME_INCOME_TYPE" x: x.mean()*100)
# Out:
# <Axes: xlabel='TARGET', ylabel='NAME_INCOME_TYPE'>
